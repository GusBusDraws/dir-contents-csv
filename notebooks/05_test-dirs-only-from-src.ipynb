# %%
# Include so all modules are re-imported before any cell is executed. 
# This is so custom modules do not have to be manually reloaded if changed.
# %load_ext autoreload
# %autoreload 2

# Import standard packaged
import os
import sys

# Import third party packages
import numpy as np
import pandas as pd

# Add parent directory to locations checked for custom modules 
# (necessary for Jupyter Notebook sessions that are not started in the parent directory)
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# Import custom packages
from src import dir_funcs

# %% [markdown]
# # Run functions on test directory

# %%
dir_funcs.get_a_dims(r'..\test-dir-00')
# Out:
# (11, 0, 2)

# %%
dir_funcs.get_dir_df(r'..\test-dir-00', dirs_only=False)
# Out:
#                  0             1             2             3
# 0   ..\test-dir-00           NaN           NaN           NaN
# 1              NaN  blank-00.txt           NaN           NaN
# 2              NaN  blank-01.txt           NaN           NaN
# 3              NaN   test-dir-01           NaN           NaN
# 4              NaN           NaN  blank-02.txt           NaN
# 5              NaN           NaN  blank-03.txt           NaN
# 6              NaN   test-dir-02           NaN           NaN
# 7              NaN           NaN  blank-04.txt           NaN
# 8              NaN           NaN  blank-05.txt           NaN
# 9              NaN           NaN  blank-06.txt           NaN
# 10             NaN           NaN   test-dir-03           NaN
# 11             NaN           NaN           NaN  blank-07.txt

# %%
dir_funcs.get_dir_df(r'..\test-dir-00', dirs_only=True)
# Out:
#                 0            1            2    3
# 0  ..\test-dir-00          NaN          NaN  NaN
# 1             NaN  test-dir-01          NaN  NaN
# 2             NaN  test-dir-02          NaN  NaN
# 3             NaN          NaN  test-dir-03  NaN

# %% [markdown]
# # Save test CSV

# %%
dir_funcs.get_dir_df(r'..\test-dir-00', dirs_only=True, csv_save_path=r'..\test-dirs-only.csv')
# Out:
# CSV saved: ..\test-dirs-only.csv
#                 0            1            2    3
# 0  ..\test-dir-00          NaN          NaN  NaN
# 1             NaN  test-dir-01          NaN  NaN
# 2             NaN  test-dir-02          NaN  NaN
# 3             NaN          NaN  test-dir-03  NaN

# %%
dir_funcs.get_a_dims(r'C:\Users\gusb\Creative Cloud Files', dirs_only=True)
# Out:
# (180, 0, 6)

# %%
dir_funcs.get_dir_df(r'C:\Users\gusb\Creative Cloud Files', dirs_only=True, csv_save_path=r'..\results\gus-cc.csv')
# Out:
# CSV saved: ..\results\gus-cc.csv
#                                       0          1              2    3    4  \
# 0    C:\Users\gusb\Creative Cloud Files        NaN            NaN  NaN  NaN
# 1                                   NaN         1x            NaN  NaN  NaN
# 2                                   NaN     300ppi            NaN  NaN  NaN
# 3                                   NaN      72ppi            NaN  NaN  NaN
# 4                                   NaN        NaN  Drawing-a-day  NaN  NaN
# ..                                  ...        ...            ...  ...  ...
# 176                                 NaN   Stickers            NaN  NaN  NaN
# 177                                 NaN        NaN       holo cat  NaN  NaN
# 178                                 NaN        NaN         Orders  NaN  NaN
# 179                                 NaN  Templates            NaN  NaN  NaN
# 180                                 NaN  Vaporwave            NaN  NaN  NaN
#
#        5    6    7
# ...

# %%
dir_funcs.get_dir_df(r'X:\GUS', dirs_only=True, csv_save_path=r'..\results\solidification-GUS-dirs-only.csv')

# %%
dir_funcs.get_dir_df(r'X:\Radiography Drive', dirs_only=True, csv_save_path=r'..\results\radoigraphy-drive-dirs-only.csv')
